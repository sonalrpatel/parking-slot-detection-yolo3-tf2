# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Wed Jun 15 04:05:47 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
# Enter github usename and password if the repo to be cloned is own private 
# from getpass import getpass
# user = getpass('GitHub user')
# password = getpass('GitHub password')
# os.environ['GITHUB_AUTH'] = user + ':' + password

os.chdir('/content')
# %ls
# Out:
# drive/  sample_data/

# %%
# clone a private repo
# !git clone https://github.com/sonalrpatel/parking-slot-detection-yolo3-tf2
# Out:
# Cloning into 'parking-slot-detection-yolo3-tf2'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 151 (delta 34), reused 141 (delta 24), pack-reused 0
# Receiving objects: 100% (151/151), 13.01 MiB | 14.52 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
# download our DarkNet weights
os.chdir('/content/parking-slot-detection-yolo3-tf2/model_data')

# !wget https://pjreddie.com/media/files/yolov3.weights

os.chdir('/content/parking-slot-detection-yolo3-tf2')
# %ls
# Out:
# --2022-06-15 04:06:34--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights.1’
#
# yolov3.weights.1    100%[===================>] 236.52M  23.1MB/s    in 11s
#
# 2022-06-15 04:06:46 (21.8 MB/s) - ‘yolov3.weights.1’ saved [248007048/248007048]
#
# convert.py  LICENSE      notebook/   requirements.txt  utils/
# get_map.py  model_data/  predict.py  summary.py        voc_annotation.py
# img/        nets/        README.md   train.py          yolo.py

# %%
# call a Python script to set up our architecture with downloaded pre-trained weights
# !python convert.py model_data/ps-4.cfg model_data/yolov3.weights model_data/yolo_weights.h5

# %%
# call a Python script to set up our architecture with downloaded pre-trained weights
# !python convert2.py data/yolov3.weights data/yolov3_coco.h5

# %%
# load data from zip to data
# !mkdir data/ps
# !unzip /content/drive/MyDrive/10_Python/00_Datasets/ps2.0.zip -d model_data/ps/

# %%
# train model
# !python train.py
# Out:
# 2.8.2
# 2022-06-15 04:16:27.381042: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Load weights model_data/yolo_weights.h5.
# Freeze the first 184 layers of total 252 layers.
# Train on 7862 samples, val on 1965 samples, with batch size 32.
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# train.py:207: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   callbacks           = [logging, checkpoint, reduce_lr, early_stopping, loss_history]
# Epoch 1/20
# ...
